# %%
# Datastructures in Python
# List or Array - List or Array starts and end with square brackets or []
# and elements in the List are seperated by comma.
# List/Array are mutable or appendable, unordered and allow duplicates
# and multi data types.
numarray=[24,78,12,15,34,8,10,78,12]
print(numarray)
chrarray=['AAA',"john",'C',"BOY",'AAA']
print(chrarray)
mixedarray=[24,"DDD","A",78,90,199,"KKK","A","A"]
print(mixedarray)
# Out:
# [24, 78, 12, 15, 34, 8, 10, 78, 12]
# ['AAA', 'john', 'C', 'BOY', 'AAA']
# [24, 'DDD', 'A', 78, 90, 199, 'KKK', 'A', 'A']

# %%
# Tupples - Tupples start and end with round brackets or paranthesis or()
# and elements are seperated by comma. Tupples are immutable and allow
# duplicates, and multi datatypes
numtupple=(24,78,12,15,34,8,10,78,12)
print(numtupple)
chrtupple=('AAA',"john",'C',"BOY",'AAA')
print(chrtupple)
mixedtupple=(24,"DDD","A",78,90,199,"KKK","A","A")
print(mixedtupple)
# Out:
# (24, 78, 12, 15, 34, 8, 10, 78, 12)
# ('AAA', 'john', 'C', 'BOY', 'AAA')
# (24, 'DDD', 'A', 78, 90, 199, 'KKK', 'A', 'A')

# %%
# Sets - Sets start and end with curly brackets or {} and elements 
# seperated by comma. Sets are mutable or appendable and do not allow
# duplicates. 
numset={24,78,12,15,34,8,10,78,12}
print(numset)
chrset={'AAA',"john",'C',"BOY",'AAA'}
print(chrset)
mixedset={24,"DDD","A",78,90,199,"KKK","A","A"}
print(mixedset)
# Out:
# {34, 8, 24, 10, 12, 78, 15}
# {'C', 'BOY', 'john', 'AAA'}
# {'A', 90, 199, 24, 'KKK', 'DDD', 78}

# %%
# Dictionary - Dictionary start and end with curly brackets or {} and 
# elements of dictionary are Key:Value pairs. Key is the character and
# value is numerical
dict_1={'Male':1,'Female':0}
print(dict_1)
# Out:
# {'Male': 1, 'Female': 0}

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# List/Array Methods
numarray.append(20)
numarray.append([50,79,100]) # Adds elements at the end of list
print(numarray)
print(numarray.count(20)) # Returns number of times element appears
print(numarray.index(20)) # Python starts with 0. Index Position 
numarray.insert(5,88) # insert element at specified position
numarray
# Out:
# [24, 78, 12, 15, 34, 8, 10, 78, 12, 20, [50, 79, 100]]
# 1
# 9
# [24, 78, 12, 15, 34, 88, 8, 10, 78, 12, 20, [50, 79, 100]]

# %%
numarray=[24,78,12,15,34,8,10,78,12]
numarray.sort()
numarray
# Out:
# [8, 10, 12, 12, 15, 24, 34, 78, 78]

# %%
# numarray.clear() removes all elements of list
numarray.pop(6) # remove element at a specified position
print(numarray)
numarray.remove(12) # removes the first item with specified value
print(numarray)
# Out:
# [8, 10, 12, 12, 15, 24, 78, 78]
# [8, 10, 12, 15, 24, 78, 78]

# %%
# Libraries 
# Pandas - Dataframe based operations library for read/write data, concat,
# reshape,replace,resample, date functions, etc. Dataframe is by default
# Rows are observations and columns are variables. Excel - Data Table.

# matplotlib.pyplot - Data Vizualization Library for creating charts 
# and most importanly resizing the plot window, adding axis labels, 
# adding title, etc.

# Numpy - Array/List based operations. All computations and calculations
# are performed by this library. Sub libraries in Numpy
# scipy.stats - Statistics in Python
# statsmodels - Timeseries or IOT Data
# sklearn - Machine Learning in Python

# io - inputoutput library for setting up working directory

# Other Libraries to be installed
# nltk, textblob, wordcloud - Natural Language Processing
# tensorflow, keras - Deep Learning & Image Processing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import io
# %cd '/Users/rajeshprabhakarkaila/Desktop/Datasets'
# Out:
# /Users/rajeshprabhakarkaila/Desktop/Datasets

# %%
NYBnB=pd.read_excel("New York AirBnB.xlsx",sheet_name="New York AirBnB")
# pd refers to Library Name
# read_excel() - predefined function. Every Function must have paranthesis
# or (). Either paranthesis will be null or arguments given within
# Function Syntax - libraryname.functionname()
# Dataframe Function Sytntax - dataframename.functionname()

# %%
NYBnB.info()
# Class - Dataframe , Rows/Observation-41533, Columns/Variables-18
# Individual Variable Data Type - int64,float64,object, datetime64[ns]
# Non Null count highlights whether a variable has missing values.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41533 entries, 0 to 41532
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              41533 non-null  int64
#  1   name                            41517 non-null  object
#  2   host_id                         41533 non-null  int64
#  3   host_name                       41527 non-null  object
#  4   neighbourhood_group             41533 non-null  object
#  5   neighbourhood                   41533 non-null  object
#  6   latitude                        41533 non-null  float64
#  7   longitude                       41533 non-null  float64
#  8   room_type                       41533 non-null  object
#  9   price                           41533 non-null  int64
#  10  minimum_nights                  41533 non-null  int64
#  11  number_of_reviews               41533 non-null  int64
#  12  last_review                     32140 non-null  datetime64[ns]
#  13  reviews_per_month               32140 non-null  float64
#  14  calculated_host_listings_count  41533 non-null  int64
#  15  availability_365                41533 non-null  int64
#  16  number_of_reviews_ltm           41533 non-null  int64
#  17  license                         1 non-null      object
# dtypes: datetime64[ns](1), float64(3), int64(8), object(6)
# memory usage: 5.7+ MB

# %%
# Indexing or Accessing Specific Rows or Columns
# Character Indexing - Accessing by Column or Variable Name. Name must
# exactly match
# Numeric Indexing - Accessing By Column or Variable Index Number. Python
# starts with 0 or Zero

# %%
# Character Indexing - 2 types 
# 1) dataframename.columnname
# 2) dataframename["columnname"] used when Variable Name has space in
# between

NYBnB.price.head() # head() - By default First 5 Rows of Data
# Out:
# 0    275
# 1     75
# 2     60
# 3     68
# 4    175
# Name: price, dtype: int64

# %%
NYBnB["price"].head()
# Out:
# 0    275
# 1     75
# 2     60
# 3     68
# 4    175
# Name: price, dtype: int64

# %%
#Character Indexing-multicolumn/variable - dataframename[["var1","var2"]]
NYBnB[['price','minimum_nights','number_of_reviews']].head(10)
# First 10 Rows of Data
# Out:
#    price  minimum_nights  number_of_reviews
# 0    275              21                  3
# 1     75               2                118
# 2     60              30                 50
# 3     68               2                559
# 4    175              30                 49
# 5     65              30                  1
# 6    124               4                218
# 7     68              30                187
# 8    220               3                316
# 9     62              30                242

# %%
# Numeric Indexing - Column Number
NYBnB.iloc[:,9].head() # :, before indicates Column/Variable Selection
# Out:
# 0    275
# 1     75
# 2     60
# 3     68
# 4    175
# Name: price, dtype: int64

# %%
NYBnB.iloc[9] # Row Selection
# Out:
# id                                                   6990
# name                              UES Beautiful Blue Room
# host_id                                             16800
# host_name                                             Cyn
# neighbourhood_group                             Manhattan
# neighbourhood                                 East Harlem
# latitude                                         40.78778
# longitude                                       -73.94759
# room_type                                    Private room
# price                                                  62
# minimum_nights                                         30
# number_of_reviews                                     242
# last_review                           2022-10-21 00:00:00
# reviews_per_month                                    1.52
# calculated_host_listings_count                          1
# availability_365                                      308
# number_of_reviews_ltm                                   8
# license                                               NaN
# Name: 9, dtype: object

# %%
# Numeric Indexing - Multicolumn/variable
NYBnB.iloc[:,[9,10,11,14,17]].head() # Column Selection
# Out:
#    price  minimum_nights  number_of_reviews  calculated_host_listings_count  \
# 0    275              21                  3                               1
# 1     75               2                118                               1
# 2     60              30                 50                               2
# 3     68               2                559                               1
# 4    175              30                 49                               3
#
#   license
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
NYBnB.iloc[[9,10,11,14,17]] # Row Selection
# Out:
#        id                                               name  host_id  \
# 9    6990                            UES Beautiful Blue Room    16800
# 10   8490   Maison des Sirenes1,bohemian, luminous apartment    25183
# 11   7801                   Sweet and Spacious Brooklyn Loft    21207
# 14   9357                               Midtown Pied-a-terre    30193
# 17  12937  1 Stop fr. Manhattan! Private Suite,Landmark B...    50124
#
#    host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 9        Cyn           Manhattan         East Harlem  40.78778  -73.94759
# 10  Nathalie            Brooklyn  Bedford-Stuyvesant  40.68462  -73.93839
# 11     Chaya            Brooklyn        Williamsburg  40.71778  -73.95680
# 14     Tommi           Manhattan      Hell's Kitchen  40.76724  -73.98664
# 17   Orestes              Queens    Long Island City  40.74757  -73.94571
#
#           room_type  price  minimum_nights  number_of_reviews last_review  \
# 9      Private room     62              30                242  2022-10-21
# 10  Entire home/apt    150               2                163  2022-11-19
# 11  Entire home/apt    395              30                  9  2011-12-28
# 14  Entire home/apt    175              30                 58  2017-08-13
# 17     Private room    146               3                350  2022-11-26
#
#     reviews_per_month  calculated_host_listings_count  availability_365  \
# 9                1.52                               1               308
# 10               1.01                               2               316
# 11               0.06                               1               332
# 14               0.36                               1                 0
# 17               2.30                               1               142
#
#     number_of_reviews_ltm license
# 9                       8     NaN
# 10                     24     NaN
# 11                      0     NaN
# 14                      0     NaN
# 17                     39     NaN

# %%
# Exploratory Data Analysis (EDA) - Descriptive Statistics, Data 
# Vizualization and Data Aggregation/Grouping/Wranggling
# EDA provides complete understanding of Data.

# Descriptive Statistics - Describe the Data. Numeric Variables -
# Univariate Statistics.
# Measures of Central Tendency (Midpoint) - Mean, Median, Mode
# Measures of Dispersion(scattering of observations around mean) -
# Variance and Standard Deviation
# Measures of Location - Quartiles, Percentiles and Deciles
# Measures of Asymmetry(how close data is to Normal Distribution/Bell Curve)
# Skewness and Kurtosis

# Mean and Median must be closer to one another as mean gets distorted by
# small or large values. IF mean is distorted median must be used
# STandard Deviation must be lower and it doesnot have fixed range and
# it depends on mathematical unit like tens,hundreds, thousands, etc.
# Positive Skewness indicates Peak of Curve is on Left Side and Negative
# Skewness indicates Peak of Curve on Right Side.
# Positive Kurtosis indicates tall and narrow peak and Negative Kurtosis
# indicates flat and wide peak

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
NYBnB.price.describe() # N, Min, Max, Mean, Median/50%, std, 25%/Q1,75%/Q3
# Significant difference between Mean and Median
# Std Deviation is High
# Median is best mid point
# Out:
# count    41533.000000
# mean       221.978282
# std        919.502236
# min          0.000000
# 25%         80.000000
# 50%        131.000000
# 75%        220.000000
# max      98159.000000
# Name: price, dtype: float64

# %%
print("Skewness",NYBnB.price.skew()) # Very High Positive Skewness
print("Kurtosis",NYBnB.price.kurt()) # Very High Positive Kurtosis
# Out:
# Skewness 78.22503185691421
# Kurtosis 7498.176026467221

# %%
NYBnB.columns # Name of the Variable/Columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %%
NYBnB[['minimum_nights', 'number_of_reviews']].describe()
# Out:
#        minimum_nights  number_of_reviews
# count    41533.000000       41533.000000
# mean        18.592204          26.204994
# std         30.699921          56.178847
# min          1.000000           0.000000
# 25%          2.000000           1.000000
# 50%         10.000000           5.000000
# 75%         30.000000          25.000000
# max       1250.000000        1666.000000

# %%
print("skewness",NYBnB[['minimum_nights','number_of_reviews']].skew())
print("kurtosis",NYBnB[['minimum_nights','number_of_reviews']].kurt())
# Out:
# skewness minimum_nights       14.331509
# number_of_reviews     5.570549
# dtype: float64
# kurtosis minimum_nights       375.692050
# number_of_reviews     65.747075
# dtype: float64

# %%
# Univariate Plots _ Line, Pie, Bar, Stacked Bar Charts, etc.
# pandas plots - dataframename.variablename.plot(kind="")
# kind=line or pie or bar or bar,stacked=True

# 3 Most Important plots 
# 1) Histogram - Bar chart of Frequency Distribution Table. Frequency
# Distribution Table has 2 Columns ClassInterval(LL - UL) & Frequency
# Histogram highlights skewness, kurtosis and outliers

# 2) Boxplot - Based on Quartiles. Q1, Q2, Q3 and InterQuartile Range are
# required for Boxplot. Boxplot highlights skewness and most importantly
# outliers. outliers are extreme values that fall outside normal datarange
# Minimum Side - Q1 - 1.5*IQR 
# Maximum Side - Q3 + 1.5*IQR

# 3) Density Curve - Based on Standard Normal Distribution Scores. Line 
# plot shows how close data is to normal distribution highlights both
# skewness and kurtosis

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
NYBnB.price.plot(kind='hist') # Histogram
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
NYBnB.price.plot(kind='box',vert=False)
# Out:
# <AxesSubplot:>

# %%
NYBnB.price.plot(kind='density')
# Out:
# <frozen importlib._bootstrap>:228: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject
# <AxesSubplot:ylabel='Density'>

# %%
NYBnB.number_of_reviews.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
NYBnB.number_of_reviews.plot(kind='box',vert=False)
# Out:
# <AxesSubplot:>

# %%
NYBnB.number_of_reviews.plot(kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
# Non Numeric Data - Only Frequency Counts and Cross Tabulations
NYBnB.room_type.value_counts()
# Out:
# Entire home/apt    23526
# Private room       17287
# Shared room          532
# Hotel room           188
# Name: room_type, dtype: int64

# %%
pd.set_option("display.max_rows",225)
NYBnB.neighbourhood.value_counts()
# Out:
# Bedford-Stuyvesant           2936
# Williamsburg                 2570
# Harlem                       1949
# Midtown                      1918
# Bushwick                     1752
# Hell's Kitchen               1533
# Upper West Side              1514
# Upper East Side              1428
# Crown Heights                1299
# East Village                 1171
# Chelsea                       889
# Lower East Side               847
# East Harlem                   821
# Greenpoint                    759
# Astoria                       727
# Washington Heights            634
# East Flatbush                 585
# Financial District            570
# Flushing                      536
# Flatbush                      517
# West Village                  516
# Long Island City              501
# Prospect-Lefferts Gardens     444
# Murray Hill                   427
# Kips Bay                      416
# East New York                 373
# Clinton Hill                  373
# Jamaica                       368
# Woodside                      364
# Theater District              363
# Ridgewood                     352
# Fort Greene                   341
# Park Slope                    333
# Sunnyside                     295
# Sunset Park                   294
# SoHo                          287
# Elmhurst                      281
# Ditmars Steinway              262
# East Elmhurst                 262
# Chinatown                     256
# Canarsie                      256
# Nolita                        243
# Gramercy                      242
# Jackson Heights               232
# Prospect Heights              228
# Greenwich Village             214
# South Slope                   206
# Cypress Hills                 195
# Morningside Heights           191
# Inwood                        190
# Carroll Gardens               184
# Gowanus                       174
# Springfield Gardens           166
# Sheepshead Bay                166
# Tribeca                       164
# Bay Ridge                     143
# Richmond Hill                 139
# Boerum Hill                   136
# Forest Hills                  133
# St. Albans                    133
# Rosedale                      124
# Brownsville                   124
# Flatiron District             120
# Windsor Terrace               116
# Arverne                       116
# Maspeth                       115
# Kensington                    112
# Flatlands                     112
# Little Italy                  108
# Wakefield                     106
# Midwood                       100
# Mott Haven                     99
# Rego Park                      97
# Ozone Park                     95
# Woodhaven                      95
# Queens Village                 94
# Brooklyn Heights               89
# Battery Park City              87
# South Ozone Park               86
# Kingsbridge                    85
# Borough Park                   83
# Corona                         80
# Bensonhurst                    76
# Bayside                        75
# Williamsbridge                 74
# Longwood                       74
# Laurelton                      73
# Cobble Hill                    72
# Fordham                        72
# Rockaway Beach                 71
# Brighton Beach                 71
# Gravesend                      69
# Downtown Brooklyn              67
# Cambria Heights                65
# Glendale                       63
# Port Morris                    58
# Stuyvesant Town                58
# Two Bridges                    57
# Concourse                      56
# Red Hook                       55
# St. George                     54
# Far Rockaway                   50
# Allerton                       47
# Clason Point                   46
# Kew Gardens                    46
# Fort Hamilton                  45
# Roosevelt Island               45
# College Point                  45
# Concourse Village              44
# Claremont Village              44
# Parkchester                    44
# Pelham Gardens                 42
# Jamaica Estates                42
# Briarwood                      41
# Baychester                     39
# Mount Hope                     39
# Tompkinsville                  39
# Kew Gardens Hills              39
# Throgs Neck                    37
# NoHo                           36
# Howard Beach                   35
# Morris Park                    35
# Vinegar Hill                   35
# Belmont                        34
# Norwood                        34
# Van Nest                       34
# Fresh Meadows                  34
# Hollis                         33
# Hunts Point                    32
# Columbia St                    32
# Edenwald                       31
# Civic Center                   31
# Mariners Harbor                30
# Tremont                        30
# West Brighton                  29
# Middle Village                 29
# Highbridge                     27
# Bath Beach                     27
# Schuylerville                  27
# DUMBO                          25
# Bayswater                      24
# Stapleton                      22
# Melrose                        22
# Morris Heights                 22
# Bronxdale                      21
# Coney Island                   21
# Bergen Beach                   20
# Morrisania                     20
# Dyker Heights                  20
# Soundview                      20
# Olinville                      19
# Bellerose                      19
# Sea Gate                       18
# Edgemere                       18
# Arrochar                       17
# Unionport                      17
# Whitestone                     16
# Randall Manor                  16
# University Heights             16
# Jamaica Hills                  16
# Eastchester                    15
# Grant City                     14
# Pelham Bay                     14
# Shore Acres                    14
# City Island                    14
# Mill Basin                     14
# Mount Eden                     13
# New Brighton                   12
# Port Richmond                  12
# Clifton                        11
# Woodlawn                       11
# Fieldston                      10
# North Riverdale                10
# East Morrisania                10
# Midland Beach                  10
# Riverdale                      10
# Navy Yard                       9
# Manhattan Beach                 9
# Concord                         9
# Marble Hill                     9
# Belle Harbor                    8
# Dongan Hills                    8
# Rosebank                        8
# Prince's Bay                    7
# Westchester Square              7
# New Dorp Beach                  7
# Castleton Corners               7
# Oakwood                         7
# Graniteville                    7
# Todt Hill                       6
# Co-op City                      6
# Douglaston                      6
# Castle Hill                     6
# West Farms                      6
# Spuyten Duyvil                  6
# Grymes Hill                     6
# Bay Terrace                     5
# Emerson Hill                    5
# Arden Heights                   5
# Eltingville                     5
# Great Kills                     4
# Huguenot                        4
# Holliswood                      4
# Breezy Point                    4
# South Beach                     4
# New Springville                 4
# Gerritsen Beach                 3
# Tottenville                     3
# Howland Hook                    3
# Richmondtown                    3
# Silver Lake                     3
# Little Neck                     2
# Country Club                    2
# Neponsit                        2
# Chelsea, Staten Island          2
# Lighthouse Hill                 2
# Willowbrook                     1
# New Dorp                        1
# Fort Wadsworth                  1
# Bull's Head                     1
# Westerleigh                     1
# Woodrow                         1
# Hollis Hills                    1
# Name: neighbourhood, dtype: int64

# %%
# Top 20 neighborhood
NYBnB.neighbourhood.value_counts().nlargest(20)
# Out:
# Bedford-Stuyvesant    2936
# Williamsburg          2570
# Harlem                1949
# Midtown               1918
# Bushwick              1752
# Hell's Kitchen        1533
# Upper West Side       1514
# Upper East Side       1428
# Crown Heights         1299
# East Village          1171
# Chelsea                889
# Lower East Side        847
# East Harlem            821
# Greenpoint             759
# Astoria                727
# Washington Heights     634
# East Flatbush          585
# Financial District     570
# Flushing               536
# Flatbush               517
# Name: neighbourhood, dtype: int64

# %%
df=NYBnB.neighbourhood.value_counts().nlargest(20)
ax=df.plot.bar(color='green')
for i in ax.containers:
    ax.bar_label(i,fontsize=7,color='orange')

# %%
# Bottom 20
df=NYBnB.neighbourhood.value_counts().nsmallest(20)
ax=df.plot.bar(color='red')
for i in ax.containers:
    ax.bar_label(i,fontsize=7,color='blue')

# %%
# Cross tabulation - Frequency Table of 2 Categorical Variables
pd.crosstab(NYBnB.neighbourhood,
            NYBnB.room_type).nlargest(20,columns="Entire home/apt")
# Out:
# room_type           Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# Bedford-Stuyvesant             1511           1          1386           38
# Williamsburg                   1447           3          1094           26
# Upper East Side                1171           1           235           21
# Midtown                        1170          44           689           15
# Hell's Kitchen                 1029          30           444           30
# Upper West Side                1015           1           472           26
# Harlem                          881           1          1044           23
# East Village                    747           1           412           11
# Crown Heights                   708           0           583            8
# Bushwick                        619           0          1103           30
# Chelsea                         606           4           270            9
# Lower East Side                 592           6           245            4
# Greenpoint                      522           5           225            7
# West Village                    458          13            44            1
# East Harlem                     440           0           366           15
# Kips Bay                        329           1            81            5
# Financial District              328           3           233            6
# Astoria                         296           1           417           13
# East Flatbush                   291           0           288            6
# Murray Hill                     291          20           108            8

# %%
df=pd.crosstab(NYBnB.neighbourhood,
            NYBnB.room_type).nlargest(20,columns="Entire home/apt")
ax=df.plot.bar(stacked=True)
for i in ax.containers:
    ax.bar_label(i,fontsize=7,color='yellow',label_type="center")

# %%
d1=pd.crosstab(NYBnB.neighbourhood,NYBnB.room_type)

# %%
d1[(d1['Entire home/apt']>=500)&(d1['Entire home/apt']<=1000)]
# Out:
# room_type        Entire home/apt  Hotel room  Private room  Shared room
# neighbourhood
# Bushwick                     619           0          1103           30
# Chelsea                      606           4           270            9
# Crown Heights                708           0           583            8
# East Village                 747           1           412           11
# Greenpoint                   522           5           225            7
# Harlem                       881           1          1044           23
# Lower East Side              592           6           245            4

# %%
NYBnB.room_type.value_counts().plot(kind='pie',autopct='%.1f%%')
# %.2f%% is for 2 decimal with % symbol
# %.1f%% is for 1 decimal with % symbol
# Out:
# <AxesSubplot:ylabel='room_type'>

# %%
# Data Aggregation - groupby() function
NYBnB.price.groupby(NYBnB.room_type).mean()
# Left side of groupby must be numerical
# Right side of groupby within paranthesis categorical variable
# Statistical Function like mean, median,std,sum, etc. must be speciifed.
# Out:
# room_type
# Entire home/apt    263.442404
# Hotel room         416.164894
# Private room       166.102042
# Shared room        135.400376
# Name: price, dtype: float64

# %%
NYBnB.price.groupby(NYBnB.room_type).mean().sort_values().plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='room_type'>

# %%
NYBnB.price.groupby(NYBnB.neighbourhood).mean().sort_values(
    ascending=False)
# Out:
# neighbourhood
# Coney Island                 3694.619048
# West Brighton                2607.000000
# Wakefield                    1008.820755
# Theater District              789.022039
# Tribeca                       711.640244
# Bellerose                     665.736842
# Fort Wadsworth                650.000000
# SoHo                          571.560976
# Murray Hill                   509.686183
# Hollis Hills                  484.000000
# Midtown                       471.783629
# Financial District            453.629825
# Navy Yard                     403.888889
# Flatiron District             402.350000
# Chelsea                       373.946007
# Riverdale                     362.000000
# Briarwood                     355.219512
# West Village                  352.364341
# Greenwich Village             343.172897
# NoHo                          335.305556
# Willowbrook                   329.000000
# Belle Harbor                  317.750000
# Downtown Brooklyn             308.074627
# DUMBO                         305.360000
# Lower East Side               297.014168
# Hell's Kitchen                296.076321
# Neponsit                      293.500000
# Nolita                        285.423868
# Bergen Beach                  280.700000
# Civic Center                  280.516129
# Red Hook                      270.127273
# Battery Park City             268.862069
# Little Italy                  261.083333
# Boerum Hill                   256.727941
# Gramercy                      255.632231
# Stapleton                     254.000000
# Vinegar Hill                  252.400000
# Brooklyn Heights              250.865169
# Longwood                      248.310811
# Cobble Hill                   246.902778
# Gowanus                       245.580460
# Kips Bay                      244.036058
# Upper East Side               242.859944
# Tottenville                   239.333333
# Upper West Side               237.494716
# Chinatown                     237.050781
# Long Island City              232.219561
# Prince's Bay                  231.428571
# Rockaway Beach                231.323944
# Carroll Gardens               226.500000
# Park Slope                    225.669670
# Columbia St                   222.468750
# East Village                  222.253629
# Todt Hill                     220.333333
# Sea Gate                      216.888889
# Stuyvesant Town               215.689655
# Eltingville                   212.600000
# Sheepshead Bay                212.108434
# Prospect Heights              207.456140
# Clinton Hill                  206.257373
# Holliswood                    199.250000
# Greenpoint                    196.009223
# Manhattan Beach               194.333333
# Far Rockaway                  193.520000
# Gerritsen Beach               193.000000
# Grymes Hill                   192.000000
# Fort Greene                   190.087977
# Spuyten Duyvil                189.333333
# Arverne                       188.698276
# Williamsburg                  187.282101
# East Harlem                   185.032887
# Jamaica Estates               183.833333
# South Slope                   180.330097
# Bedford-Stuyvesant            180.091621
# Howard Beach                  174.485714
# New Brighton                  173.666667
# Dongan Hills                  173.375000
# Bayside                       172.146667
# Windsor Terrace               169.784483
# Edgemere                      166.500000
# Port Richmond                 165.750000
# Canarsie                      164.984375
# Forest Hills                  164.030075
# Lighthouse Hill               164.000000
# Tompkinsville                 163.846154
# Kew Gardens Hills             162.692308
# Clifton                       161.363636
# Bay Terrace                   158.200000
# Howland Hook                  157.333333
# Middle Village                157.206897
# Schuylerville                 154.777778
# Harlem                        154.136993
# Oakwood                       150.857143
# Breezy Point                  150.000000
# Crown Heights                 149.278676
# Mill Basin                    147.785714
# Whitestone                    146.750000
# Flatlands                     146.339286
# Little Neck                   146.000000
# Fresh Meadows                 145.941176
# Queens Village                145.670213
# South Ozone Park              145.581395
# Two Bridges                   145.245614
# Jamaica                       145.179348
# Unionport                     143.882353
# Midland Beach                 143.400000
# Brownsville                   142.637097
# Roosevelt Island              142.333333
# City Island                   141.928571
# Mott Haven                    139.939394
# Flatbush                      139.019342
# Kensington                    138.473214
# Eastchester                   138.333333
# North Riverdale               138.200000
# Randall Manor                 137.500000
# East New York                 135.938338
# St. Albans                    135.819549
# New Springville               135.750000
# Pelham Bay                    135.642857
# Woodlawn                      134.909091
# Port Morris                   133.948276
# Great Kills                   133.000000
# Gravesend                     132.927536
# Rosedale                      132.838710
# East Flatbush                 132.570940
# Springfield Gardens           132.337349
# Arrochar                      132.117647
# Morningside Heights           131.895288
# Sunset Park                   130.877551
# Jamaica Hills                 130.125000
# Mount Hope                    127.820513
# Flushing                      127.121269
# Shore Acres                   126.142857
# Cambria Heights               125.646154
# Olinville                     125.578947
# Astoria                       124.817056
# Ditmars Steinway              123.927481
# Concord                       123.888889
# St. George                    123.722222
# East Elmhurst                 123.087786
# Pelham Gardens                122.833333
# Throgs Neck                   122.513514
# Prospect-Lefferts Gardens     122.349099
# Kew Gardens                   122.347826
# Van Nest                      122.117647
# Cypress Hills                 122.082051
# Washington Heights            120.829653
# Maspeth                       120.513043
# Morris Heights                119.727273
# Glendale                      119.428571
# Emerson Hill                  119.400000
# East Morrisania               119.100000
# College Point                 119.022222
# Williamsbridge                118.337838
# Bay Ridge                     117.251748
# Mount Eden                    116.923077
# Baychester                    115.717949
# Silver Lake                   115.666667
# Rosebank                      115.500000
# Arden Heights                 115.400000
# Parkchester                   115.136364
# Huguenot                      115.000000
# Laurelton                     114.328767
# Bath Beach                    114.074074
# Richmondtown                  113.000000
# Castleton Corners             113.000000
# Morrisania                    112.950000
# Bushwick                      112.242580
# Ozone Park                    112.147368
# Fort Hamilton                 111.111111
# Ridgewood                     110.923295
# Clason Point                  110.239130
# Edenwald                      110.161290
# New Dorp Beach                109.285714
# Castle Hill                   109.166667
# Woodrow                       109.000000
# Fieldston                     108.900000
# Allerton                      108.872340
# Dyker Heights                 108.350000
# Concourse                     107.642857
# Marble Hill                   107.222222
# Belmont                       107.029412
# Brighton Beach                107.028169
# Corona                        106.687500
# Rego Park                     106.185567
# Tremont                       105.833333
# Richmond Hill                 105.568345
# Bensonhurst                   105.039474
# Norwood                       103.705882
# Bayswater                     103.291667
# Sunnyside                     103.122034
# South Beach                   100.500000
# Kingsbridge                    99.541176
# Borough Park                   99.361446
# Morris Park                    98.914286
# Co-op City                     98.666667
# Melrose                        97.272727
# Soundview                      96.100000
# Claremont Village              94.613636
# Woodhaven                      93.557895
# Midwood                        93.060000
# Hollis                         92.242424
# Elmhurst                       92.167260
# Fordham                        91.263889
# University Heights             91.062500
# Westerleigh                    91.000000
# Concourse Village              90.818182
# Westchester Square             90.285714
# Jackson Heights                89.581897
# Inwood                         88.568421
# Highbridge                     88.000000
# Bronxdale                      87.761905
# Mariners Harbor                86.300000
# Hunts Point                    85.750000
# Woodside                       85.230769
# Chelsea, Staten Island         85.000000
# Graniteville                   82.428571
# Douglaston                     82.166667
# West Farms                     74.333333
# Country Club                   70.000000
# Grant City                     61.285714
# Bull's Head                    60.000000
# New Dorp                       40.000000
# Name: price, dtype: float64

# %%
# What is the Average Number of reviews for each room type
np.round(NYBnB.number_of_reviews.groupby(NYBnB.room_type).mean(),2)
# np.round(output,decimal)
# Out:
# room_type
# Entire home/apt    27.05
# Hotel room         55.65
# Private room       24.93
# Shared room        19.97
# Name: number_of_reviews, dtype: float64

# %%
# What is the Median price for each room type
NYBnB.price.groupby(NYBnB.room_type).median()
# Out:
# room_type
# Entire home/apt    180.0
# Hotel room         335.0
# Private room        78.0
# Shared room         65.0
# Name: price, dtype: float64
